# %%
import nsepy as nse
import pprint as p
import pandas as pd

# %%
data = nse.get_quote('reliance')

# %%
type(data)
# Out:
# dict

# %%
rel = pd.DataFrame.from_dict(data)

# %%
rel.head()
# Out:
#   tradedDate                                               data  \
# 0  07JAN2022  {'pricebandupper': '2,658.15', 'symbol': 'RELI...
#
#                                              optLink otherSeries  \
# 0  /marketinfo/sym_map/symbolMapping.jsp?symbol=R...          EQ
#
#                                              futLink        lastUpdateTime
# 0  /live_market/dynaContent/live_watch/get_quote/...  07-JAN-2022 16:00:00

# %%
rel2 = pd.DataFrame.from_dict(data['data'])

# %%
rel2.shape
# Out:
# (1, 68)

# %%
from nsepy import get_history
from datetime import date
data = get_history(symbol="SBIN", start=date(2015,1,1), end=date(2015,1,31))
data[['Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from nsepy import get_history
import nsepy as nse
from datetime import date
data = get_history(symbol="SBIN", start=date(2022,1,1), end=date(2022,1,31))
data.head()
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2022-01-03   SBIN     EQ      460.45  462.00  472.00  460.10  471.50  470.80
# 2022-01-04   SBIN     EQ      470.80  472.50  484.70  471.05  483.75  483.50
# 2022-01-05   SBIN     EQ      483.50  481.90  495.00  479.15  491.70  492.40
# 2022-01-06   SBIN     EQ      492.40  487.70  494.40  485.40  491.35  491.70
# 2022-01-07   SBIN     EQ      491.70  493.45  501.95  489.45  491.25  491.25
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2022-01-03  467.17  13124509  6.131388e+14  168001             4183151
# 2022-01-04  479.89  23296671  1.117985e+15  246431             7667089
# 2022-01-05  489.50  24694169  1.208792e+15  240463             8282621
# 2022-01-06  490.44  18190843  8.921514e+14  195393             5957550
# 2022-01-07  495.38  22746330  1.126809e+15  254165             6908394
#
#             %Deliverble
# Date
# 2022-01-03       0.3187
# ...

# %%
stock_lst = ['ADANIPORTS','ASIANPAINT','AXISBANK','BAJAJ-AUTO','BAJAJFINSV']

# %%
from nsepy import get_history
from datetime import date

for i in stock_lst:
    data = get_history(symbol=i, start=date(2015,1,1), end=date(2015,1,31))
    print(data)
#     data[['Close']].plot()
# Out:
#                 Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2015-01-01  ADANIPORTS     EQ      319.05  319.00  322.50  316.25  318.35
# 2015-01-02  ADANIPORTS     EQ      319.55  319.35  325.80  318.05  319.30
# 2015-01-05  ADANIPORTS     EQ      319.35  320.45  327.50  319.35  323.75
# 2015-01-06  ADANIPORTS     EQ      323.80  321.65  331.45  315.60  321.70
# 2015-01-07  ADANIPORTS     EQ      321.85  321.95  328.70  317.40  321.75
# 2015-01-08  ADANIPORTS     EQ      321.10  326.00  337.30  323.55  336.70
# 2015-01-09  ADANIPORTS     EQ      334.55  339.90  343.10  327.35  331.30
# 2015-01-12  ADANIPORTS     EQ      331.15  332.15  335.75  325.55  327.45
# 2015-01-13  ADANIPORTS     EQ      328.45  330.20  331.30  320.75  324.00
# 2015-01-14  ADANIPORTS     EQ      323.00  324.00  333.90  322.65  332.80
# 2015-01-15  ADANIPORTS     EQ      331.25  334.00  337.30  326.25  330.00
# 2015-01-16  ADANIPORTS     EQ      330.60  329.80  334.60  326.00  331.00
# ...
