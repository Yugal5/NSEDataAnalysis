# %%
from nsepy import get_history
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date

# %%
data = get_history(symbol='INFY',start=date(2021,1,12),end=date(2022,1,14)).reset_index()

# %%
# data.head()
# data.groupby('')
# data.info()
data['month'] = pd.to_datetime(data['Date'])

# %%
data.head()
# Out:
#          Date Symbol Series  Prev Close     Open     High      Low     Last  \
# 0  2021-01-12   INFY     EQ     1376.20  1378.00  1378.00  1360.00  1376.50
# 1  2021-01-13   INFY     EQ     1371.75  1373.85  1392.80  1360.00  1388.65
# 2  2021-01-14   INFY     EQ     1387.15  1360.00  1384.00  1318.45  1370.50
# 3  2021-01-15   INFY     EQ     1370.50  1360.00  1364.45  1340.00  1343.40
# 4  2021-01-18   INFY     EQ     1344.95  1338.00  1340.00  1306.00  1311.00
#
#      Close     VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  1371.75  1369.78   8309868  1.138271e+15  264378             3655022
# 1  1387.15  1378.96  14442997  1.991624e+15  304458             6490234
# 2  1370.50  1359.34  27521697  3.741122e+15  530803            10370390
# 3  1344.95  1352.96  15018441  2.031942e+15  278300             8103557
# 4  1312.05  1320.52   8861765  1.170215e+15  230056             3963352
#
#    %Deliverble      month
# 0       0.4398 2021-01-12
# ...

# %%
data['month'] = data['month'].dt.month

# %%
# d1 = data.groupby('month'.split('-',1))['month']

# %%
# data['Date'] = '2021-02-15'

# %%
d1 = data.groupby('month')

# %%
len(d1)
# Out:
# 12

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['Month'] = data['Date'].dt.month

# %%
data['Month'] = data['Month'].map({1:'January',
                                  2:'February',
                                  3:'March',
                                  4:'April',
                                  5:'May',
                                  6:'June',
                                  7:'July',
                                  8:'August',
                                  9:'September',
                                  10:'Octomber',
                                  11:'November',
                                  12:'December'})

# %%
d1 = data.groupby('Month')['Open','Close','Low','Month','Date']
# Out:
# C:\Users\India\AppData\Local\Temp/ipykernel_4560/1834013302.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   d1 = data.groupby('Month')['Open','Close','Low','Month','Date']

# %%
sns.histplot(x = data['Open'] , bins=20)
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Count'>

# %%
plt.figure(figsize=(12,7))
sns.heatmap(data.corr(),annot=True)

plt.show()

# %%
data.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.998179  0.996838  0.996360  0.994725
# Open                  0.998179  1.000000  0.998193  0.997628  0.995903
# High                  0.996838  0.998193  1.000000  0.997859  0.998214
# Low                   0.996360  0.997628  0.997859  1.000000  0.998477
# Last                  0.994725  0.995903  0.998214  0.998477  1.000000
# Close                 0.994735  0.995752  0.998135  0.998498  0.999898
# VWAP                  0.996498  0.997656  0.999268  0.999304  0.999249
# Volume               -0.218980 -0.220136 -0.203954 -0.240931 -0.219674
# Turnover              0.021134  0.023107  0.040239  0.002273  0.023656
# Trades               -0.027323 -0.034230 -0.021651 -0.062311 -0.042306
# Deliverable Volume   -0.071808 -0.071718 -0.059395 -0.090688 -0.074258
# %Deliverble           0.482488  0.477755  0.464077  0.482069  0.469186
# ...
